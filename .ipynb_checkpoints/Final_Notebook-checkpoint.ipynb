# %% [markdown]
# # Chest X-Ray Images (Pneumonia)
# **Authors:** Carlos McCrum, Jared Mitchell, Andrew Bernklau
# ***

# %% [markdown]
# ## Overview
# We've been tasked to build a model to classify images that consist of x-rays of infected and healthy lungs at our local hospital. The data contains thousands of images Mendeley Data. We start by preprocessing the images and splitting into training and test sets. Next we build different models to see what performs best, including Logistic Regression, Random Forest and Neural Networks. Convolutional neural networks performed best and had the best accuracy. So our recommendations would include convolutional neural networks for classification as they performed the best.
#
#
#
# ***

# %% [markdown]
# ## Business Problem
#
# The number of Pneumonia cases increased in the last few years with 1.5 million ER visits and 2 million deaths indicating around 16% increase. The goal of our project is to build a image classification model that can correctly identify between x-rays of infected and healthy lungs so we can lower these numbers. It's important that our model has high accuracy. With a low accuracy our model would misdiagnose too much or fail to diagnose someone who has pneumonia. Classifying images requires a lot of images for more accurate modeling and we are limited in the number of images we have at our disposal. We chose this route to see if modeling could help classify whether a person does or does not have a the Pneumonia to help radiology technicians at our local hospital.
#
# ***

# %% [markdown]
# ![b8e5fa58305913.59f7787a47652.gif](attachment:b8a3bc20-cd25-421f-b2eb-54abc342d776.gif)

# %% [markdown]
# ## Data Understanding
#
# Our data comes from Mendeley Data, it contains a few thousand images Chest X-Ray described and analyzed in "Identifying Medical Diagnoses and Treatable Diseases by Image-Based Deep Learning". The images are split into a training set and a testing set of independent patients. Images are labeled as (disease)-(randomized patient ID)-(image number by this patient). We are going to be classifying whether the images fall into the two classes either "NORMAL" or "PNEUMONIA"". We start buy preprocessing the data, then spliting it into training and validation sets then build a few different models to see what model perfoms best.
#
#
#
# ***

# %%
# Import packages
import numpy as np 
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import plot_confusion_matrix
from tqdm import tqdm 
import code.preparation as prep
import code.visualization as viz
np.random.seed(123)
from tensorflow.keras import preprocessing
from time import time
import pickle

from keras import layers
from keras import models
from keras import optimizers
import datetime
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import img_to_array
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from keras import backend as K
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
# Seed value
seed_value= 0

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)


# 5. Configure a new global `tensorflow` session
from keras import backend as K
session_conf =  tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# ## Data Preparation
#
# We preprocessed the data in two ways. One for our logistic and random forest models splitting our data the standard way, and the other we preprocessed our images into tensors for our neural network modeling. We did it this way to have our images properly set for our models for the best performance. There were very few images that would not load and were discarded, there were no other null values in our data.
#
# ***

# %% [markdown]
# ### Preprocessing for Logitstic and Random Forest

# %% [markdown]
# Set path for our images.

# %%
train_path = 'data/chest_xray/train/'
test_path = 'data/chest_xray/test/'
val_path = 'data/chest_xray/val'

# %%
train_gen, test_gen, val_gen = prep.img_data_gen(train_path, test_path, val_path)
# Out:
# Found 5219 images belonging to 2 classes.
# Found 5219 images belonging to 2 classes.
# Found 625 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %% [markdown]
# - Create datasets and reshape for our models to interpret.

# %%
# create the data sets
start = time()
val_images, val_labels = tqdm(next(val_gen))
test_images, test_labels = tqdm(next(test_gen))
train_images, train_labels = tqdm(next(train_gen))
end = time()

print("Total run Time:", round((end - start)/60, 2), "Min")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 11244.78it/s]
# 100%|██████████| 2/2 [00:00<00:00, 23237.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 18517.90it/s]
# Total run Time: 0.01 Min

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# For data augmentation we take our images and alter them in many different ways to give our model more diversity in training images. This will give our model more to work with since we don't have enough data for a proper learning.

# %%
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (4, 202800)
# (4, 202800)
# (4, 202800)

# %%
train_y = np.reshape(train_labels[:,0], (10434,1))
test_y = np.reshape(test_labels[:,0], (624,1))
val_y = np.reshape(val_labels[:,0], (16,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-6df94f31a5dd> in <module>
# ----> 1 train_y = np.reshape(train_labels[:,0], (10434,1))
#       2 test_y = np.reshape(test_labels[:,0], (624,1))
#       3 val_y = np.reshape(val_labels[:,0], (16,1))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 4 into shape (10434,1)

# %%
viz.class_inbalance(train_labels)
# Out:
# Pneumonia    0.74286
# Normal       0.25714
# dtype: float64
# <AxesSubplot:ylabel='count'>

# %%
viz.preview_img(train_images, train_y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-54cd6b49ccbe> in <module>
# ----> 1 viz.preview_img(train_images_, train_y)
#
# ~/Python Projects/X-Ray-Pneumonia-Classification/code/visualization.py in preview_img(train_images, train_y)
#      20     plt.figure(figsize=(10, 10))
#      21     for i in range(9):
# ---> 22         ax = plt.subplot(3, 3, i + 1)
#      23         plt.imshow(array_to_img(train_images[i]))
#      24         if train_y[i] == 0:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1285     else:
#    1286         # we have exhausted the known Axes and none match, make a new one!
# -> 1287         ax = fig.add_subplot(*args, **kwargs)
#    1288
#    1289     fig.sca(ax)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     779             projection_class, pkw = self._process_projection_requirements(
#     780                 *args, **kwargs)
# --> 781             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     782             key = (projection_class, pkw)
#     783         return self._add_axes_internal(ax, key)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     621         # (see colorbar.py):
#     622         self._colorbars = []
# --> 623         self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     624
#     625         # this call may differ for non-sep axes, e.g., polar
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_base.py in _gen_axes_spines(self, locations, offset, units)
#    1129         Intended to be overridden by new projection types.
#    1130         """
# -> 1131         return OrderedDict((side, mspines.Spine.linear_spine(self, side))
#    1132                            for side in ['left', 'right', 'bottom', 'top'])
#    1133
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#    1129         Intended to be overridden by new projection types.
#    1130         """
# -> 1131         return OrderedDict((side, mspines.Spine.linear_spine(self, side))
#    1132                            for side in ['left', 'right', 'bottom', 'top'])
#    1133
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/spines.py in linear_spine(cls, axes, spine_type, **kwargs)
#     435         else:
#     436             raise ValueError('unable to make path for spine "%s"' % spine_type)
# --> 437         result = cls(axes, spine_type, path, **kwargs)
#     438         result.set_visible(rcParams['axes.spines.{0}'.format(spine_type)])
#     439
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/spines.py in __init__(self, axes, spine_type, path, **kwargs)
#      51             %(Patch_kwdoc)s
#      52         """
# ---> 53         super().__init__(**kwargs)
#      54         self.axes = axes
#      55         self.set_figure(self.axes.figure)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      92         else:
#      93             self.set_edgecolor(edgecolor)
# ---> 94             self.set_facecolor(facecolor)
#      95         # unscaled dashes.  Needed to scale dash patterns by lw
#      96         self._us_dashes = None
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/patches.py in set_facecolor(self, color)
#     366         """
#     367         self._original_facecolor = color
# --> 368         self._set_facecolor(color)
#     369
#     370     def set_color(self, c):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/patches.py in _set_facecolor(self, color)
#     354             color = mpl.rcParams['patch.facecolor']
#     355         alpha = self._alpha if self._fill else 0
# --> 356         self._facecolor = colors.to_rgba(color, alpha)
#     357         self.stale = True
#     358
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     197         from matplotlib import rcParams
#     198         prop_cycler = rcParams['axes.prop_cycle']
# --> 199         colors = prop_cycler.by_key().get('color', ['k'])
#     200         c = colors[int(c[1:]) % len(colors)]
#     201     try:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/cycler.py in by_key(self)
#     369         keys = self.keys
#     370         # change this to dict comprehension when drop 2.6
# --> 371         out = dict((k,  list()) for k in keys)
#     372
#     373         for d in self:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/cycler.py in <genexpr>(.0)
#     369         keys = self.keys
#     370         # change this to dict comprehension when drop 2.6
# --> 371         out = dict((k,  list()) for k in keys)
#     372
#     373         for d in self:
#
# KeyboardInterrupt:

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train_gen.classes),
                                        y = train_gen.classes                                                    
                                    )
class_weights = dict(zip(np.unique(train_gen.classes), class_weights))
class_weights
# Out:
# {0: 1.9444858420268256, 1: 0.6730719628578798}

# %% [markdown]
# ## Data Modeling
# We start off with a simple logistical regression model to see how it performs, we next move on to random forest modeling to see if we can get a better accuracy score, last we try convolutional neural networks to see how accurate we can make it so we don't have any false positives or false negatives. These are all models that work for classification, let's see how they perform.
#
# ***

# %% [markdown]
# Start by running a logistical regression model with l2 regularization as our baseline.

# %%
prep.logistic_regression_l2(train_img, train_y, test_img, test_y)

# %% [markdown]
# Very good start, now we move on to our random forest to see if we can improve the accuracy of the results.

# %%
RF_model = prep.random_forest(train_img, train_y, test_img, test_y)
# Out:
# Cross validation score for Random Forest: [0.864      0.848      0.88       0.96       0.91129032]
# Test score of random forest model: 0.8205128205128205

# %% [markdown]
# Plot confusion matrix to visualize at how well our model classified our images.

# %%
plot_confusion_matrix(RF_model, test_img, test_y);

# %% [markdown]
# Now we will try a convolutional neural network (CNN) as it is exceptional at image processing. We can utilize the convolutional operation to detect more complex features within the image. Let's start with one Conv2d and one MaxPooling2D layer.

# %% [markdown]
# #### Baseline CNN

# %%
history = prep.first_cnn(train_images_, train_y, val_images, val_y, test_images, test_y)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 19s 857ms/step - loss: 0.9615 - acc: 0.7156 - val_loss: 1.0632 - val_acc: 0.5000
# Epoch 2/20
# 20/20 [==============================] - 17s 830ms/step - loss: 0.8583 - acc: 0.7437 - val_loss: 0.9742 - val_acc: 0.6250
# Epoch 3/20
# 20/20 [==============================] - 17s 836ms/step - loss: 0.7287 - acc: 0.8313 - val_loss: 1.4664 - val_acc: 0.5625
# Epoch 4/20
# 20/20 [==============================] - 17s 852ms/step - loss: 0.7559 - acc: 0.8219 - val_loss: 1.3476 - val_acc: 0.5625
# Epoch 5/20
# 20/20 [==============================] - 43s 2s/step - loss: 0.7012 - acc: 0.8375 - val_loss: 1.1717 - val_acc: 0.5625
# Epoch 6/20
# 20/20 [==============================] - 63s 3s/step - loss: 0.6202 - acc: 0.8906 - val_loss: 0.8582 - val_acc: 0.6875
# Epoch 7/20
# 20/20 [==============================] - 39s 2s/step - loss: 0.6547 - acc: 0.8625 - val_loss: 0.9372 - val_acc: 0.6875
# Epoch 8/20
# 20/20 [==============================] - 27s 1s/step - loss: 0.6611 - acc: 0.8469 - val_loss: 0.8685 - val_acc: 0.6875
# Epoch 9/20
# 20/20 [==============================] - 31s 2s/step - loss: 0.6396 - acc: 0.8594 - val_loss: 0.9744 - val_acc: 0.6250
# Epoch 10/20
# 20/20 [==============================] - 25s 1s/step - loss: 0.5953 - acc: 0.8687 - val_loss: 1.0431 - val_acc: 0.6250
# Epoch 11/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.6137 - acc: 0.8594 - val_loss: 1.3693 - val_acc: 0.5625
# Epoch 12/20
# 20/20 [==============================] - 25s 1s/step - loss: 0.5750 - acc: 0.8781 - val_loss: 0.8960 - val_acc: 0.6250
# Epoch 13/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.5552 - acc: 0.8781 - val_loss: 0.7949 - val_acc: 0.8125
# Epoch 14/20
# 20/20 [==============================] - 29s 1s/step - loss: 0.5553 - acc: 0.8969 - val_loss: 1.2231 - val_acc: 0.6250
# Epoch 15/20
# 20/20 [==============================] - 27s 1s/step - loss: 0.5202 - acc: 0.8969 - val_loss: 0.8074 - val_acc: 0.6250
# Epoch 16/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.4680 - acc: 0.9219 - val_loss: 1.1298 - val_acc: 0.6250
# Epoch 17/20
# 20/20 [==============================] - 20s 1s/step - loss: 0.5195 - acc: 0.9000 - val_loss: 0.9354 - val_acc: 0.6250
# Epoch 18/20
# 20/20 [==============================] - 19s 965ms/step - loss: 0.5321 - acc: 0.9031 - val_loss: 0.8133 - val_acc: 0.6250
# Epoch 19/20
# 20/20 [==============================] - 45s 2s/step - loss: 0.5153 - acc: 0.8687 - val_loss: 0.9372 - val_acc: 0.6250
# Epoch 20/20
# 20/20 [==============================] - 57s 3s/step - loss: 0.5273 - acc: 0.8625 - val_loss: 1.0651 - val_acc: 0.6250
# 327/327 [==============================] - 842s 3s/step - loss: 0.4655 - acc: 0.9052
# Training Score of first convolution neural network: [0.46550190448760986, 0.9052137136459351]
# 20/20 [==============================] - 59s 3s/step - loss: 0.7740 - acc: 0.7821
# Test Score of first convolution neural network: [0.7739989757537842, 0.7820512652397156]

# %%
viz.accuracy_and_losses(history);

# %% [markdown]
# That CNN did nearly as good as the logisitic regression. Now we will add some layers and tuning to the CNN for improvement.

# %%
train_gen, test_gen, val_gen = prep.img_data_gen_batched(train_path, test_path, val_path)
# Out:
# Found 5219 images belonging to 2 classes.
# Found 625 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
final_H, model = prep.final_model(train_gen, val_gen, test_gen)
# Out:
# Epoch 1/20
# 50/50 [==============================] - 94s 2s/step - loss: 0.6827 - accuracy: 0.2500 - val_loss: 1.1770 - val_accuracy: 0.5000
# Epoch 2/20
# 50/50 [==============================] - 90s 2s/step - loss: 0.3592 - accuracy: 0.2350 - val_loss: 2.8979 - val_accuracy: 0.5000
# Epoch 3/20
# 50/50 [==============================] - 93s 2s/step - loss: 0.3400 - accuracy: 0.2875 - val_loss: 4.7797 - val_accuracy: 0.5000
# Epoch 4/20
# 50/50 [==============================] - 92s 2s/step - loss: 0.3825 - accuracy: 0.2450 - val_loss: 7.3350 - val_accuracy: 0.5000
# Epoch 5/20
# 19/50 [==========>...................] - ETA: 57s - loss: 0.3733 - accuracy: 0.2434
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-853ef2af53b9> in <module>
# ----> 1 history = prep.final_model(train_images, train_y, test_images, test_y, val_images, val_y)
#
# ~/Python Projects/X-Ray-Pneumonia-Classification/code/preparation.py in final_model(train_images, train_y, test_images, test_y, val_images, val_y)
#     134     history = model.fit(train_images,
#     135                         train_y,
# --> 136                         steps_per_epoch=50,
#     137                         epochs=20,
#     138                         batch_size=8,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1270                 _r=1):
#    1271               callbacks.on_train_batch_begin(step)
# -> 1272               tmp_logs = self.train_function(iterator)
#    1273               if data_handler.should_sync:
#    1274                 context.async_wait()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
viz.accuracy_and_losses(final_H);

# %%
start = time()

model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), input_shape=(260, 260, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D((2,2) , padding = 'valid'))

model.add(layers.RandomRotation(factor=0.15))
model.add(layers.RandomTranslation(height_factor=0.1, width_factor=0.1))
model.add(layers.RandomFlip())

model.add(layers.Conv2D(64 , (3,3) , padding = 'valid' , activation = None))
model.add(layers.Dropout(0.1))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D((2,2) , padding = 'valid'))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(2, activation='sigmoid'))


model.build([None, 260, 260, 3])
model.summary()

model.compile(loss='binary_crossentropy', 
              metrics=['accuracy'],
              optimizer=SGD(.0001, .9))


model.fit(train_gen,
          steps_per_epoch=train_gen.n // train_gen.batch_size,
          epochs=20,
          validation_data=val_gen,
          validation_steps=val_gen.n // val_gen.batch_size,
          class_weight=class_weights)



print(f"\nTest Score: {model.evaluate(test_gen)[1]}")
end = time()
print("Run Time:", round((end - start)/60, 2), "Min")
# Out:
# Model: "sequential_188"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_169 (Conv2D)         (None, 258, 258, 32)      896
#
#  batch_normalization_84 (Bat  (None, 258, 258, 32)     128
#  chNormalization)
#
#  max_pooling2d_104 (MaxPooli  (None, 129, 129, 32)     0
#  ng2D)
#
#  random_rotation_16 (RandomR  (None, 129, 129, 32)     0
#  otation)
#
#  random_translation_16 (Rand  (None, 129, 129, 32)     0
#  omTranslation)
#
#  random_flip_19 (RandomFlip)  (None, 129, 129, 32)     0
#
#  conv2d_170 (Conv2D)         (None, 127, 127, 64)      18496
#
#  dropout_51 (Dropout)        (None, 127, 127, 64)      0
#
#  batch_normalization_85 (Bat  (None, 127, 127, 64)     256
#  chNormalization)
#
#  max_pooling2d_105 (MaxPooli  (None, 63, 63, 64)       0
#  ng2D)
#
#  flatten_153 (Flatten)       (None, 254016)            0
#
#  dense_218 (Dense)           (None, 256)               65028352
#
#  dense_219 (Dense)           (None, 128)               32896
#
#  dense_220 (Dense)           (None, 64)                8256
#
#  dense_221 (Dense)           (None, 2)                 130
#
# =================================================================
# Total params: 65,089,410
# Trainable params: 65,089,218
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/20
# 1304/1304 [==============================] - 1432s 1s/step - loss: 0.4168 - accuracy: 0.8117 - val_loss: 1.5620 - val_accuracy: 0.6250
# Epoch 2/20
# 1304/1304 [==============================] - 1431s 1s/step - loss: 0.3197 - accuracy: 0.8619 - val_loss: 1.4449 - val_accuracy: 0.5625
# Epoch 3/20
# 1304/1304 [==============================] - 1424s 1s/step - loss: 0.2759 - accuracy: 0.8813 - val_loss: 0.8895 - val_accuracy: 0.6250
# Epoch 4/20
# 1304/1304 [==============================] - 1429s 1s/step - loss: 0.2615 - accuracy: 0.8901 - val_loss: 2.2806 - val_accuracy: 0.6250
# Epoch 5/20
# 1304/1304 [==============================] - 1426s 1s/step - loss: 0.2478 - accuracy: 0.8949 - val_loss: 1.5811 - val_accuracy: 0.6250
# Epoch 6/20
# 1304/1304 [==============================] - 1390s 1s/step - loss: 0.2449 - accuracy: 0.9014 - val_loss: 1.2528 - val_accuracy: 0.6250
# Epoch 7/20
# 1304/1304 [==============================] - 1341s 1s/step - loss: 0.2276 - accuracy: 0.9085 - val_loss: 0.8719 - val_accuracy: 0.6875
# Epoch 8/20
# 1304/1304 [==============================] - 1338s 1s/step - loss: 0.2173 - accuracy: 0.9103 - val_loss: 0.6311 - val_accuracy: 0.6875
# Epoch 9/20
# 1304/1304 [==============================] - 1338s 1s/step - loss: 0.2232 - accuracy: 0.9116 - val_loss: 0.8039 - val_accuracy: 0.6250
# Epoch 10/20
# 1304/1304 [==============================] - 12908s 10s/step - loss: 0.2029 - accuracy: 0.9162 - val_loss: 1.9445 - val_accuracy: 0.6250
# Epoch 11/20
# 1304/1304 [==============================] - 9830s 8s/step - loss: 0.1962 - accuracy: 0.9208 - val_loss: 1.9343 - val_accuracy: 0.6250
# Epoch 12/20
# 1304/1304 [==============================] - 3399s 3s/step - loss: 0.1970 - accuracy: 0.9202 - val_loss: 0.2630 - val_accuracy: 0.9375
# Epoch 13/20
# 1304/1304 [==============================] - 1467s 1s/step - loss: 0.1868 - accuracy: 0.9264 - val_loss: 0.4381 - val_accuracy: 0.7500
# Epoch 14/20
# 1304/1304 [==============================] - 1479s 1s/step - loss: 0.1908 - accuracy: 0.9239 - val_loss: 0.3692 - val_accuracy: 0.7500
# Epoch 15/20
# 1304/1304 [==============================] - 1454s 1s/step - loss: 0.1837 - accuracy: 0.9281 - val_loss: 0.9651 - val_accuracy: 0.6250
# Epoch 16/20
# 1304/1304 [==============================] - 1416s 1s/step - loss: 0.1879 - accuracy: 0.9256 - val_loss: 0.5851 - val_accuracy: 0.6875
# Epoch 17/20
# 1304/1304 [==============================] - 1468s 1s/step - loss: 0.1799 - accuracy: 0.9289 - val_loss: 0.6038 - val_accuracy: 0.6875
# Epoch 18/20
# 1304/1304 [==============================] - 1556s 1s/step - loss: 0.1775 - accuracy: 0.9285 - val_loss: 0.6667 - val_accuracy: 0.6875
# Epoch 19/20
# 1304/1304 [==============================] - 1446s 1s/step - loss: 0.1805 - accuracy: 0.9292 - val_loss: 0.5722 - val_accuracy: 0.6875
# Epoch 20/20
# 1304/1304 [==============================] - 1437s 1s/step - loss: 0.1628 - accuracy: 0.9340 - val_loss: 0.2601 - val_accuracy: 0.9375
# 157/157 [==============================] - 39s 250ms/step - loss: 0.2891 - accuracy: 0.8944
#
# Test Score: 0.8944000005722046
# Run Time: 840.87 Min

# %%
Y_pred = model.predict_generator(test_gen, test_gen.n // test_gen.batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_gen.classes, y_pred))
print('Classification Report')
target_names = ['Pneumonia', 'Normal']
print(classification_report(test_gen.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 76 159]
#  [140 250]]
# Classification Report
#               precision    recall  f1-score   support
#
#    Pneumonia       0.35      0.32      0.34       235
#       Normal       0.61      0.64      0.63       390
#
#     accuracy                           0.52       625
#    macro avg       0.48      0.48      0.48       625
# weighted avg       0.51      0.52      0.52       625

# %%
from sklearn.metrics import auc, roc_curve

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(['Normal', 'Pneumonia']): # all_labels: no of the labels, for ex. ['cat', 'dog', 'rat']
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

# calling
test_gen.reset() # resetting generator
y_pred = model.predict_generator(val_gen, verbose = True)
y_pred = np.argmax(y_pred, axis=1)
multiclass_roc_auc_score(val_gen.classes, y_pred)
# Out:
# 4/4 [==============================] - 0s 74ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-e7ae72937b45> in <module>
#      20 y_pred = model.predict_generator(val_gen, verbose = True)
#      21 y_pred = np.argmax(y_pred, axis=1)
# ---> 22 multiclass_roc_auc_score(val_gen.classes, y_pred)
#
# <ipython-input-70-e7ae72937b45> in multiclass_roc_auc_score(y_test, y_pred, average)
#      11
#      12     for (idx, c_label) in enumerate(['Normal', 'Pneumonia']): # all_labels: no of the labels, for ex. ['cat', 'dog', 'rat']
# ---> 13         fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
#      14         c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
#      15     c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %% [markdown]
# ## Evaluation
# Our best model came out to 90% accuracy score. After using dropout and other regularization techniques we our final model did better than either our logistic regression or random forest models. This shows us that our convolutional neural networks are working great by classifying our images. Our baseline with logistic regression was 84% which still fairy good, though on our final model we've made a significant improvement. With a 90% accuracy our model will be able to help our business problem but not solve it, because our model could never be as good as a human in this circumstance.
#
# ***

# %% [markdown]
# ## Conclusions
#
# Should not be used as a diagnosis, it is a good educational tool for new students or radiologist technicians. It has a good accuracy but doesn't fully solve our business problem because for our model to be used professionally in the medical field it would have to have near perfect accuracy. With more data and resources we might be able to get a more accurate model, that is something we can look into for future research.
# ***
